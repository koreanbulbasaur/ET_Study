# %%
import os, sys
current_dir = os.path.dirname(os.path.abspath("../module.py"))
sys.path.append(current_dir)
from module import *

# %%
train_datagen = ImageDataGenerator(rescale=1./255, # 주어진 이밎 크기를 설정
                                   horizontal_flip=True, # 수평 대칭 이미지를 50% 확률로 만들어 추가
                                   width_shift_range=0.1, # 전체 크기의 15% 범위에서 좌우로 이동함
                                   height_shift_range=0.1 # 마찬가지로 위아래로 이동함
                                   )

# %%
train_generator = train_datagen.flow_from_directory(
    './data-ch20/train',
    target_size=(150, 150),
    batch_size=5,
    class_mode='binary'
)
# Out:
# Found 160 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    './data-ch20/test',
    target_size=(150, 150),
    batch_size=5,
    class_mode='binary'
)
# Out:
# Found 120 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(32,(3, 3), input_shape=(150, 150, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(learning_rate=0.0002),
              metrics=['accuracy'])
ealry_stopping_callback = EarlyStopping(monitor='val_loss', patience=5)
history = model.fit(train_generator,
                    epochs=100,
                    validation_data=test_generator,
                    validation_steps=10,
                    callbacks=[ealry_stopping_callback])
# Out:
# Epoch 1/100
# 32/32 [==============================] - 4s 103ms/step - loss: 0.7130 - accuracy: 0.5188 - val_loss: 0.6927 - val_accuracy: 0.5400
# Epoch 2/100
# 32/32 [==============================] - 3s 79ms/step - loss: 0.6926 - accuracy: 0.5250 - val_loss: 0.6859 - val_accuracy: 0.5000
# Epoch 3/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.6890 - accuracy: 0.5562 - val_loss: 0.6903 - val_accuracy: 0.4800
# Epoch 4/100
# 32/32 [==============================] - 3s 81ms/step - loss: 0.6775 - accuracy: 0.6062 - val_loss: 0.6519 - val_accuracy: 0.5800
# Epoch 5/100
# 32/32 [==============================] - 2s 76ms/step - loss: 0.6405 - accuracy: 0.6313 - val_loss: 0.6049 - val_accuracy: 0.7000
# Epoch 6/100
# 32/32 [==============================] - 2s 76ms/step - loss: 0.6375 - accuracy: 0.6500 - val_loss: 0.6003 - val_accuracy: 0.7200
# Epoch 7/100
# 32/32 [==============================] - 3s 78ms/step - loss: 0.5798 - accuracy: 0.7500 - val_loss: 0.6049 - val_accuracy: 0.6200
# Epoch 8/100
# 32/32 [==============================] - 2s 76ms/step - loss: 0.6025 - accuracy: 0.6812 - val_loss: 0.5465 - val_accuracy: 0.7600
# Epoch 9/100
# 32/32 [==============================] - 2s 76ms/step - loss: 0.5589 - accuracy: 0.7625 - val_loss: 0.4604 - val_accuracy: 0.8400
# Epoch 10/100
# 32/32 [==============================] - 2s 77ms/step - loss: 0.4300 - accuracy: 0.8562 - val_loss: 0.3537 - val_accuracy: 0.9200
# Epoch 11/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.3852 - accuracy: 0.8062 - val_loss: 0.3748 - val_accuracy: 0.8800
# Epoch 12/100
# 32/32 [==============================] - 3s 78ms/step - loss: 0.3619 - accuracy: 0.8813 - val_loss: 0.2815 - val_accuracy: 0.9000
# Epoch 13/100
# 32/32 [==============================] - 2s 75ms/step - loss: 0.2831 - accuracy: 0.9312 - val_loss: 0.4041 - val_accuracy: 0.7800
# Epoch 14/100
# 32/32 [==============================] - 3s 85ms/step - loss: 0.3111 - accuracy: 0.8687 - val_loss: 0.2210 - val_accuracy: 0.9000
# Epoch 15/100
# 32/32 [==============================] - 3s 88ms/step - loss: 0.2191 - accuracy: 0.9312 - val_loss: 0.2097 - val_accuracy: 0.9400
# Epoch 16/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1774 - accuracy: 0.9438 - val_loss: 0.1147 - val_accuracy: 0.9600
# Epoch 17/100
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1553 - accuracy: 0.9563 - val_loss: 0.1987 - val_accuracy: 0.9200
# Epoch 18/100
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1980 - accuracy: 0.9250 - val_loss: 0.2842 - val_accuracy: 0.8200
# Epoch 19/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.1477 - accuracy: 0.9500 - val_loss: 0.1271 - val_accuracy: 0.9600
# Epoch 20/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1819 - accuracy: 0.9250 - val_loss: 0.0814 - val_accuracy: 1.0000
# Epoch 21/100
# 32/32 [==============================] - 3s 82ms/step - loss: 0.1242 - accuracy: 0.9563 - val_loss: 0.0975 - val_accuracy: 0.9400
# Epoch 22/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.0848 - accuracy: 0.9750 - val_loss: 0.0729 - val_accuracy: 0.9800
# Epoch 23/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.1988 - accuracy: 0.9438 - val_loss: 0.0494 - val_accuracy: 1.0000
# Epoch 24/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.1212 - accuracy: 0.9750 - val_loss: 0.1241 - val_accuracy: 0.9600
# Epoch 25/100
# 32/32 [==============================] - 3s 84ms/step - loss: 0.0953 - accuracy: 0.9625 - val_loss: 0.0789 - val_accuracy: 0.9800
# Epoch 26/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.1045 - accuracy: 0.9688 - val_loss: 0.0398 - val_accuracy: 1.0000
# Epoch 27/100
# 32/32 [==============================] - 3s 83ms/step - loss: 0.0966 - accuracy: 0.9500 - val_loss: 0.1262 - val_accuracy: 0.9200
# Epoch 28/100
# 32/32 [==============================] - 3s 87ms/step - loss: 0.1249 - accuracy: 0.9438 - val_loss: 0.1175 - val_accuracy: 0.9400
# Epoch 29/100
# 32/32 [==============================] - 3s 85ms/step - loss: 0.0853 - accuracy: 0.9812 - val_loss: 0.0699 - val_accuracy: 0.9800
# Epoch 30/100
# 32/32 [==============================] - 3s 85ms/step - loss: 0.1008 - accuracy: 0.9688 - val_loss: 0.0677 - val_accuracy: 0.9800
# Epoch 31/100
# 32/32 [==============================] - 3s 86ms/step - loss: 0.1069 - accuracy: 0.9750 - val_loss: 0.0848 - val_accuracy: 0.9600

# %%
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

# %%
x_len = np.arange(len(y_loss))
plt.plot(x_len, y_vloss, marker='.', c='red', label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c='blue', label='Trainset_loss')
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
import os, sys
current_dir = os.path.dirname(os.path.abspath("../module.py"))
sys.path.append(current_dir)
from module import *

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,)
train_generator = train_datagen.flow_from_directory(
    './data-ch20/train',
    target_size=(150, 150),
    batch_size=5,
    class_mode='binary')
# Out:
# Found 160 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    './data-ch20/test',
    target_size=(150, 150),
    batch_size=5,
    class_mode='binary')
# Out:
# Found 120 images belonging to 2 classes.

# %%
transfer_model = VGG16(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
transfer_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %%
finetune_model = models.Sequential()
finetune_model.add(transfer_model)
finetune_model.add(Flatten())
finetune_model.add(Dense(64))
finetune_model.add(Activation('relu'))
finetune_model.add(Dropout(0.5))
finetune_model.add(Dense(1))
finetune_model.add(Activation('sigmoid'))
finetune_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 64)                524352
#
#  activation (Activation)     (None, 64)                0
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
#  activation_1 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 15,239,105
# Trainable params: 524,417
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
finetune_model.compile(loss='binary_crossentropy', optimizer=optimizers.Adam(learning_rate=0.0002), metrics=['accuracy'])

ealry_stopping_callback = EarlyStopping(monitor='val_loss', patience=5)

# %%
history = finetune_model.fit(
    train_generator,
    epochs=20,
    validation_data=test_generator,
    validation_steps=10,
    callbacks=[ealry_stopping_callback]
)
# Out:
# Epoch 1/20
# 32/32 [==============================] - 16s 465ms/step - loss: 0.6817 - accuracy: 0.5562 - val_loss: 0.5400 - val_accuracy: 0.8400
# Epoch 2/20
# 32/32 [==============================] - 15s 476ms/step - loss: 0.4793 - accuracy: 0.8062 - val_loss: 0.5400 - val_accuracy: 0.7600
# Epoch 3/20
# 32/32 [==============================] - 16s 495ms/step - loss: 0.4214 - accuracy: 0.8000 - val_loss: 0.3822 - val_accuracy: 0.8800
# Epoch 4/20
# 32/32 [==============================] - 15s 483ms/step - loss: 0.4220 - accuracy: 0.7875 - val_loss: 0.3756 - val_accuracy: 0.8600
# Epoch 5/20
# 32/32 [==============================] - 16s 494ms/step - loss: 0.3555 - accuracy: 0.8500 - val_loss: 0.3589 - val_accuracy: 0.8600
# Epoch 6/20
# 32/32 [==============================] - 16s 501ms/step - loss: 0.2976 - accuracy: 0.9125 - val_loss: 0.2400 - val_accuracy: 0.9400
# Epoch 7/20
# 32/32 [==============================] - 14s 432ms/step - loss: 0.3033 - accuracy: 0.8875 - val_loss: 0.2972 - val_accuracy: 0.8400
# Epoch 8/20
# 32/32 [==============================] - 14s 440ms/step - loss: 0.2326 - accuracy: 0.9375 - val_loss: 0.2718 - val_accuracy: 0.9000
# Epoch 9/20
# 32/32 [==============================] - 16s 497ms/step - loss: 0.2305 - accuracy: 0.9187 - val_loss: 0.3961 - val_accuracy: 0.7600
# Epoch 10/20
# 32/32 [==============================] - 16s 510ms/step - loss: 0.2462 - accuracy: 0.9187 - val_loss: 0.3597 - val_accuracy: 0.8200
# Epoch 11/20
# 32/32 [==============================] - 15s 483ms/step - loss: 0.2751 - accuracy: 0.9000 - val_loss: 0.2020 - val_accuracy: 0.9200
# Epoch 12/20
# 32/32 [==============================] - 15s 485ms/step - loss: 0.1942 - accuracy: 0.9563 - val_loss: 0.1528 - val_accuracy: 0.9400
# Epoch 13/20
# 32/32 [==============================] - 16s 498ms/step - loss: 0.2182 - accuracy: 0.9250 - val_loss: 0.2069 - val_accuracy: 0.9400
# Epoch 14/20
# 32/32 [==============================] - 15s 473ms/step - loss: 0.2076 - accuracy: 0.9375 - val_loss: 0.1533 - val_accuracy: 0.9400
# Epoch 15/20
# 32/32 [==============================] - 15s 474ms/step - loss: 0.1436 - accuracy: 0.9312 - val_loss: 0.1245 - val_accuracy: 0.9600
# Epoch 16/20
# 32/32 [==============================] - 15s 484ms/step - loss: 0.1997 - accuracy: 0.9312 - val_loss: 0.1773 - val_accuracy: 0.9400
# Epoch 17/20
# 32/32 [==============================] - 15s 460ms/step - loss: 0.1589 - accuracy: 0.9438 - val_loss: 0.1359 - val_accuracy: 0.9600
# Epoch 18/20
# 32/32 [==============================] - 16s 505ms/step - loss: 0.1369 - accuracy: 0.9688 - val_loss: 0.1299 - val_accuracy: 0.9600
# Epoch 19/20
# 32/32 [==============================] - 15s 482ms/step - loss: 0.1685 - accuracy: 0.9250 - val_loss: 0.3631 - val_accuracy: 0.8400
# Epoch 20/20
# 32/32 [==============================] - 15s 483ms/step - loss: 0.1944 - accuracy: 0.9312 - val_loss: 0.1728 - val_accuracy: 0.9400

# %%
y_vloss = history.history['val_loss']
y_loss = history.history['loss']
x_len = np.arange(len(y_loss))
plt.plot(x_len, y_vloss, marker='.', c='red', label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c='blue', label='Trainset_loss')
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

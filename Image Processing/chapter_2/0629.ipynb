# %%
import sys
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./data/puppy.bmp')

h, w = img.shape[:2]
x = w // 2
y = h // 2

# 빨간색 박스
# img[30:100, 30:200] = 0, 0, 255

img[367:470, 360:440] = 255, 192, 255
img[367:470, 390:400] = 0, 0, 0

# 영역 그리기
# x, y, w, h = cv2.selectROI('img', img)
# print(x, y, w, h)

if img is None:
    print('image read failed')
    sys.exit()

cv2.imshow('img', img)


cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# img1 = np.zeros((400, 600, 3), dtype=np.uint8)
#
# cv2.imshow('img1', img1)
#
# cv2.waitKey()
# cv2.destroyAllWindows()

# %% [markdown]
# img2 = np.zeros((400, 600, 3), dtype=np.uint8)
#
# cv2.imshow('img1', img1)
#
# cv2.waitKey()
# cv2.destroyAllWindows()
